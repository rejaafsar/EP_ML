# %%
from scipy import linalg
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X_train=np.array([[0,0,0]])
Y_train=np.array([[0,0]])
#X_train5=np.array([[0,0,0,0,0]])
Y_train5=np.array([[0,0,0,0]])
i=0

# %%
############## Non EP points generation ######################

p=0.1
q=1.01
d=.1
m=0
n=0
q=0.1


#print("p","\t","q","\t","d","\t","rig1","\t","rig2","\t","rig3","\t","rig4","\n")
for m in range(20000):
   # q=1.0+(p**2)/d
    #if q<5:
        #i=i+1
        H=np.array([[1j*d,p,0,0],[p,1j,q,0],[0,q,-1j,p],[0,0,p,-1j*d]])
        Evals,LEvecs,REvecs=linalg.eig(H,left=True, right=True)
        rig1=(np.dot(np.conjugate(LEvecs[:,0]),REvecs[:,0]))/(np.dot(np.conjugate(REvecs[:,0]),REvecs[:,0]))
        rig2=(np.dot(np.conjugate(LEvecs[:,1]),REvecs[:,1]))/(np.dot(np.conjugate(REvecs[:,1]),REvecs[:,1]))
        rig3=(np.dot(np.conjugate(LEvecs[:,2]),REvecs[:,2]))/(np.dot(np.conjugate(REvecs[:,2]),REvecs[:,2]))
        rig4=(np.dot(np.conjugate(LEvecs[:,3]),REvecs[:,3]))/(np.dot(np.conjugate(REvecs[:,3]),REvecs[:,3]))
        
        #print(p,"\t",q,"\t",d,"\t",np.abs(rig1),"\t",np.abs(rig2),"\t",np.abs(rig3),"\t",np.abs(rig4),"\n")
       # print("m=",m,"\n")
        arr_x=np.array([[p,q,d]])
        arr_y=np.array([[-np.log(np.abs(rig1)),-np.log(np.abs(rig4))]])
        arr_y5=np.array([[-np.log(np.abs(rig1)),-np.log(np.abs(rig2)),-np.log(np.abs(rig3)),-np.log(np.abs(rig4))]])
        X_train=np.append(X_train,arr_x,axis=0)
        Y_train=np.append(Y_train,arr_y,axis=0)
        Y_train5=np.append(Y_train5,arr_y5,axis=0)
        p=round(np.random.uniform(0,5), 3)
        d=round(np.random.uniform(0,5), 3)
        q=round(np.random.uniform(0,5), 3)

# %%
X_train.shape
# Out:
# (20001, 3)

# %%
Data=np.concatenate((X_train,Y_train5),axis=1)
df = pd.DataFrame(Data)
df
# Out:
#            0      1      2         3         4         5         6
# 0      0.000  0.000  0.000  0.000000  0.000000  0.000000  0.000000
# 1      0.100  0.100  0.100  0.030650  0.025868  0.030650  0.025868
# 2      1.290  1.279  2.836  1.208881  1.208881  1.208881  1.208881
# 3      3.610  3.381  1.039  0.179593  0.192244  0.179593  0.192244
# 4      3.695  1.450  3.930  0.187281  0.187281  0.187281  0.187281
# ...      ...    ...    ...       ...       ...       ...       ...
# 19996  0.439  2.644  3.628  0.022892  0.101128  0.101128  0.022892
# 19997  3.494  2.414  3.852  0.492094  0.492094  0.492094  0.492094
# 19998  2.168  1.709  1.514  0.497075  0.497075  0.497075  0.497075
# 19999  4.075  4.784  1.595  0.120600  0.190901  0.120600  0.190901
# 20000  2.907  4.790  3.473  0.224013  0.224013  0.486405  0.486405
#
# [20001 rows x 7 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
                                ############# 2nd order EP generation
X_train=np.array([[0,0,0]])
Y_train=np.array([[0,0]])
#X_train5=np.array([[0,0,0,0,0]])
Y_train5=np.array([[0,0,0,0]])
i=0

# %%
p=0.1
q=1
d=0
m=0
n=0
q=0.1

# %%
for m in range(5000):
    p=round(np.random.uniform(0,5), 3)
    d=round(np.random.uniform(0,5), 3)
    q=1.0+(p**2)/d
    if q<5:
        i=i+1
        H=np.array([[1j*d,p,0,0],[p,1j,q,0],[0,q,-1j,p],[0,0,p,-1j*d]])
        Evals,LEvecs,REvecs=linalg.eig(H,left=True, right=True)
        rig1=(np.dot(np.conjugate(LEvecs[:,0]),REvecs[:,0]))/(np.dot(np.conjugate(REvecs[:,0]),REvecs[:,0]))
        rig2=(np.dot(np.conjugate(LEvecs[:,1]),REvecs[:,1]))/(np.dot(np.conjugate(REvecs[:,1]),REvecs[:,1]))
        rig3=(np.dot(np.conjugate(LEvecs[:,2]),REvecs[:,2]))/(np.dot(np.conjugate(REvecs[:,2]),REvecs[:,2]))
        rig4=(np.dot(np.conjugate(LEvecs[:,3]),REvecs[:,3]))/(np.dot(np.conjugate(REvecs[:,3]),REvecs[:,3]))
        
        #print(p,"\t",q,"\t",d,"\t",np.abs(rig1),"\t",np.abs(rig2),"\t",np.abs(rig3),"\t",np.abs(rig4),"\n")
           # print("m=",m,"\n")
        arr_x=np.array([[p,q,d]])
        arr_y=np.array([[-np.log(np.abs(rig1)),-np.log(np.abs(rig4))]])
        arr_y5=np.array([[-np.log(np.abs(rig1)),-np.log(np.abs(rig2)),-np.log(np.abs(rig3)),-np.log(np.abs(rig4))]])
        X_train=np.append(X_train,arr_x,axis=0)
        Y_train=np.append(Y_train,arr_y,axis=0)
        Y_train5=np.append(Y_train5,arr_y5,axis=0)

# %%
X_train.shape
# Out:
# (7373, 3)

# %%
Data=np.concatenate((X_train,Y_train5),axis=1)
df2 = pd.DataFrame(Data)
df2
# Out:
#           0         1      2         3          4          5          6
# 0     0.000  0.000000  0.000  0.000000   0.000000   0.000000   0.000000
# 1     1.985  2.465312  2.689  1.111623  18.348307  18.348307   1.111623
# 2     2.621  3.768900  2.481  0.296042   0.296042  17.394741  17.394741
# 3     2.948  3.880578  3.017  0.388699   0.388699  17.548068  17.548068
# 4     2.224  2.116770  4.429  1.548736  18.807033  18.807033   1.548736
# ...     ...       ...    ...       ...        ...        ...        ...
# 7368  0.182  1.007137  4.641  0.004558  17.708941  17.708941   0.004558
# 7369  1.418  1.621745  3.234  1.077564  18.609168  18.609168   1.077564
# 7370  0.935  1.216500  4.038  0.186814  17.547029  17.547029   0.186814
# 7371  1.753  2.574287  1.952  0.531156   0.531156  17.570191  17.570191
# 7372  0.912  1.440309  1.889  2.235532  19.107307  19.107307   2.235532
#
# [7373 rows x 7 columns]

# %%
B = df2.drop(df2.index[5000:])
B
# Out:
#           0         1      2         3          4          5          6
# 0     0.000  0.000000  0.000  0.000000   0.000000   0.000000   0.000000
# 1     1.985  2.465312  2.689  1.111623  18.348307  18.348307   1.111623
# 2     2.621  3.768900  2.481  0.296042   0.296042  17.394741  17.394741
# 3     2.948  3.880578  3.017  0.388699   0.388699  17.548068  17.548068
# 4     2.224  2.116770  4.429  1.548736  18.807033  18.807033   1.548736
# ...     ...       ...    ...       ...        ...        ...        ...
# 4995  0.812  1.421575  1.564  4.857415   4.857415  19.511928  19.511928
# 4996  3.242  3.187422  4.805  1.926616  18.447006  18.447006   1.926616
# 4997  0.795  1.425893  1.484  4.960922  19.397633  19.397633   4.960922
# 4998  3.512  3.505921  4.922  1.438063  18.218753  18.218753   1.438063
# 4999  1.551  1.596479  4.033  0.652255  18.006360  18.006360   0.652255
#
# [5000 rows x 7 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
B.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# C=B.drop((B[(B[3]<15) & (B[3]>1)].index))
# C=C.drop((C[(C[4]<15) & (C[4]>1)].index))
# C

# %%
# %matplotlib inline 
# import matplotlib.pyplot as plt
# C.hist(bins=50, figsize=(20,15))
# plt.show()

# %%
temp_df=df
temp_df=temp_df.append(B)
temp_df
# Out:
#           0         1      2         3          4          5          6
# 0     0.000  0.000000  0.000  0.000000   0.000000   0.000000   0.000000
# 1     0.100  0.100000  0.100  0.030650   0.025868   0.030650   0.025868
# 2     1.290  1.279000  2.836  1.208881   1.208881   1.208881   1.208881
# 3     3.610  3.381000  1.039  0.179593   0.192244   0.179593   0.192244
# 4     3.695  1.450000  3.930  0.187281   0.187281   0.187281   0.187281
# ...     ...       ...    ...       ...        ...        ...        ...
# 4995  0.812  1.421575  1.564  4.857415   4.857415  19.511928  19.511928
# 4996  3.242  3.187422  4.805  1.926616  18.447006  18.447006   1.926616
# 4997  0.795  1.425893  1.484  4.960922  19.397633  19.397633   4.960922
# 4998  3.512  3.505921  4.922  1.438063  18.218753  18.218753   1.438063
# 4999  1.551  1.596479  4.033  0.652255  18.006360  18.006360   0.652255
#
# [25001 rows x 7 columns]

# %%
df02=temp_df
df02
# Out:
#           0         1      2         3          4          5          6
# 0     0.000  0.000000  0.000  0.000000   0.000000   0.000000   0.000000
# 1     0.100  0.100000  0.100  0.030650   0.025868   0.030650   0.025868
# 2     1.290  1.279000  2.836  1.208881   1.208881   1.208881   1.208881
# 3     3.610  3.381000  1.039  0.179593   0.192244   0.179593   0.192244
# 4     3.695  1.450000  3.930  0.187281   0.187281   0.187281   0.187281
# ...     ...       ...    ...       ...        ...        ...        ...
# 4995  0.812  1.421575  1.564  4.857415   4.857415  19.511928  19.511928
# 4996  3.242  3.187422  4.805  1.926616  18.447006  18.447006   1.926616
# 4997  0.795  1.425893  1.484  4.960922  19.397633  19.397633   4.960922
# 4998  3.512  3.505921  4.922  1.438063  18.218753  18.218753   1.438063
# 4999  1.551  1.596479  4.033  0.652255  18.006360  18.006360   0.652255
#
# [25001 rows x 7 columns]

# %%
df02[3]=df02[3]/df02[3].max()
df02[4]=df02[4]/df02[4].max()
df02[5]=df02[5]/df02[5].max()
df02[6]=df02[6]/df02[6].max()    
 
df02["X"]=df02[3]+df02[4]+df02[5]+df02[6]
df02
# Out:
#           0         1      2         3         4         5         6         X
# 0     0.000  0.000000  0.000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1     0.100  0.100000  0.100  0.000828  0.000730  0.001324  0.001117  0.003999
# 2     1.290  1.279000  2.836  0.032657  0.034125  0.052215  0.052215  0.171212
# 3     3.610  3.381000  1.039  0.004852  0.005427  0.007757  0.008304  0.026339
# 4     3.695  1.450000  3.930  0.005059  0.005287  0.008089  0.008089  0.026524
# ...     ...       ...    ...       ...       ...       ...       ...       ...
# 4995  0.812  1.421575  1.564  0.131221  0.137118  0.842773  0.842773  1.953884
# 4996  3.242  3.187422  4.805  0.052047  0.520732  0.796776  0.083216  1.452770
# 4997  0.795  1.425893  1.484  0.134017  0.547566  0.837836  0.214276  1.733695
# 4998  3.512  3.505921  4.922  0.038849  0.514288  0.786917  0.062114  1.402168
# 4999  1.551  1.596479  4.033  0.017620  0.508293  0.777744  0.028173  1.331829
#
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
df02.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#****************************************************EP-4 data generation

# %%
                               
X_train=np.array([[0,0,0]])
Y_train=np.array([[0,0]])
#X_train5=np.array([[0,0,0,0,0]])
Y_train5=np.array([[0,0,0,0]])
i=0

# %%
i=0
p=0.1
q=1
d=0
m=0
n=0
q=0.1

# %%
############## Non EP points generation ######################

p=0.1
q=1.01
d=.1
m=0
n=0
q=0.1


#print("p","\t","q","\t","d","\t","rig1","\t","rig2","\t","rig3","\t","rig4","\n")
for m in range(20000):
   # q=1.0+(p**2)/d
    #if q<5:
        #i=i+1
        H=np.array([[1j*d,p,0,0],[p,1j,q,0],[0,q,-1j,p],[0,0,p,-1j*d]])
        Evals,LEvecs,REvecs=linalg.eig(H,left=True, right=True)
        rig1=(np.dot(np.conjugate(LEvecs[:,0]),REvecs[:,0]))/(np.dot(np.conjugate(REvecs[:,0]),REvecs[:,0]))
        rig2=(np.dot(np.conjugate(LEvecs[:,1]),REvecs[:,1]))/(np.dot(np.conjugate(REvecs[:,1]),REvecs[:,1]))
        rig3=(np.dot(np.conjugate(LEvecs[:,2]),REvecs[:,2]))/(np.dot(np.conjugate(REvecs[:,2]),REvecs[:,2]))
        rig4=(np.dot(np.conjugate(LEvecs[:,3]),REvecs[:,3]))/(np.dot(np.conjugate(REvecs[:,3]),REvecs[:,3]))
        
        #print(p,"\t",q,"\t",d,"\t",np.abs(rig1),"\t",np.abs(rig2),"\t",np.abs(rig3),"\t",np.abs(rig4),"\n")
       # print("m=",m,"\n")
        arr_x=np.array([[p,q,d]])
        arr_y=np.array([[-np.log(np.abs(rig1)),-np.log(np.abs(rig4))]])
        arr_y5=np.array([[-np.log(np.abs(rig1)),-np.log(np.abs(rig2)),-np.log(np.abs(rig3)),-np.log(np.abs(rig4))]])
        X_train=np.append(X_train,arr_x,axis=0)
        Y_train=np.append(Y_train,arr_y,axis=0)
        Y_train5=np.append(Y_train5,arr_y5,axis=0)
        p=round(np.random.uniform(0,5), 3)
        d=round(np.random.uniform(0,5), 3)
        q=round(np.random.uniform(0,5), 3)

# %%
Data=np.concatenate((X_train,Y_train5),axis=1)
df0 = pd.DataFrame(Data)
df0
# Out:
#            0      1      2         3         4         5         6
# 0      0.000  0.000  0.000  0.000000  0.000000  0.000000  0.000000
# 1      0.100  0.100  0.100  0.030650  0.025868  0.030650  0.025868
# 2      1.865  0.591  2.058  0.079380  0.079380  0.079380  0.079380
# 3      0.720  3.516  3.452  0.038991  0.078107  0.078107  0.038991
# 4      1.203  4.352  1.648  0.057729  0.057729  0.075240  0.075240
# ...      ...    ...    ...       ...       ...       ...       ...
# 19996  2.082  4.262  2.829  0.169682  0.284755  0.169682  0.284755
# 19997  4.239  2.233  1.506  1.066642  1.066642  1.066642  1.066642
# 19998  2.457  3.993  3.070  0.277397  0.277397  0.543424  0.543424
# 19999  1.092  0.936  3.501  0.515922  0.761361  0.761361  0.515922
# 20000  0.991  2.380  4.175  0.118505  0.233734  0.233734  0.118505
#
# [20001 rows x 7 columns]

# %%
X_train=np.array([[0,0,0]])
Y_train=np.array([[0,0]])
#X_train5=np.array([[0,0,0,0,0]])
Y_train5=np.array([[0,0,0,0]])
i=0

# %%
i=0
p=0.1
q=1
d=0
m=0
n=0
q=0.1

# %%
for m in range(5000):
    #p=round(np.random.uniform(0,5), 3)
    d=round(np.random.uniform(0,5), 3)
    #q=1.0+(p**2)/d
    q=(np.sqrt((d**2+(1+d)**2))-d)
    p=np.sqrt(d*(q-1))
    if q<5:
        i=i+1
        H=np.array([[1j*d,p,0,0],[p,1j,q,0],[0,q,-1j,p],[0,0,p,-1j*d]])
        Evals,LEvecs,REvecs=linalg.eig(H,left=True, right=True)
        rig1=(np.dot(np.conjugate(LEvecs[:,0]),REvecs[:,0]))/(np.dot(np.conjugate(REvecs[:,0]),REvecs[:,0]))
        rig2=(np.dot(np.conjugate(LEvecs[:,1]),REvecs[:,1]))/(np.dot(np.conjugate(REvecs[:,1]),REvecs[:,1]))
        rig3=(np.dot(np.conjugate(LEvecs[:,2]),REvecs[:,2]))/(np.dot(np.conjugate(REvecs[:,2]),REvecs[:,2]))
        rig4=(np.dot(np.conjugate(LEvecs[:,3]),REvecs[:,3]))/(np.dot(np.conjugate(REvecs[:,3]),REvecs[:,3]))
       # print(p,"\t",q,"\t",d,"\t",-np.log(np.abs(rig1)),"\t",-np.log(np.abs(rig2)),"\t",-np.log(np.abs(rig3)),"\t",-np.log(np.abs(rig4)),"\n")

        #print(p,"\t",q,"\t",d,"\t",np.abs(rig1),"\t",np.abs(rig2),"\t",np.abs(rig3),"\t",np.abs(rig4),"\n")
           # print("m=",m,"\n")
        arr_x=np.array([[p,q,d]])
        arr_y=np.array([[-np.log(np.abs(rig1)),-np.log(np.abs(rig4))]])
        arr_y5=np.array([[-np.log(np.abs(rig1)),-np.log(np.abs(rig2)),-np.log(np.abs(rig3)),-np.log(np.abs(rig4))]])
        X_train=np.append(X_train,arr_x,axis=0)
        Y_train=np.append(Y_train,arr_y,axis=0)
        Y_train5=np.append(Y_train5,arr_y5,axis=0)

# %%
X_train.shape
# Out:
# (5001, 3)

# %%
Data=np.concatenate((X_train,Y_train5),axis=1)
df4 = pd.DataFrame(Data)
df4
# Out:
#              0         1      2          3          4          5          6
# 0     0.000000  0.000000  0.000   0.000000   0.000000   0.000000   0.000000
# 1     2.009370  2.175078  3.436  26.254812  26.255030  26.255196  26.254974
# 2     2.103669  2.234772  3.584  27.164627  27.164556  27.164963  27.164870
# 3     0.469842  1.226877  0.973  25.424270  25.424370  25.424230  25.424352
# 4     2.767260  2.656441  4.623  26.648931  26.648690  26.648945  26.648699
# ...        ...       ...    ...        ...        ...        ...        ...
# 4996  2.735916  2.636475  4.574  26.260627  26.260736  26.260846  26.260705
# 4997  1.655878  1.952060  2.880  26.321231  26.321171  26.321158  26.321102
# 4998  1.591194  1.911410  2.778  26.465750  26.466026  26.465634  26.465847
# 4999  0.507910  1.248769  1.037  26.334622  26.334778  26.334373  26.334474
# 5000  0.798073  1.420688  1.514  26.478705  26.478582  26.479194  26.479071
#
# [5001 rows x 7 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
df4.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df04=df0
df04=df04.append(df4)
df04
# Out:
#              0         1      2          3          4          5          6
# 0     0.000000  0.000000  0.000   0.000000   0.000000   0.000000   0.000000
# 1     0.100000  0.100000  0.100   0.030650   0.025868   0.030650   0.025868
# 2     1.865000  0.591000  2.058   0.079380   0.079380   0.079380   0.079380
# 3     0.720000  3.516000  3.452   0.038991   0.078107   0.078107   0.038991
# 4     1.203000  4.352000  1.648   0.057729   0.057729   0.075240   0.075240
# ...        ...       ...    ...        ...        ...        ...        ...
# 4996  2.735916  2.636475  4.574  26.260627  26.260736  26.260846  26.260705
# 4997  1.655878  1.952060  2.880  26.321231  26.321171  26.321158  26.321102
# 4998  1.591194  1.911410  2.778  26.465750  26.466026  26.465634  26.465847
# 4999  0.507910  1.248769  1.037  26.334622  26.334778  26.334373  26.334474
# 5000  0.798073  1.420688  1.514  26.478705  26.478582  26.479194  26.479071
#
# [25002 rows x 7 columns]

# %%
df04[3]=df04[3]/df04[3].max()
df04[4]=df04[4]/df04[4].max()
df04[5]=df04[5]/df04[5].max()
df04[6]=df04[6]/df04[6].max()    
 
df04["X"]=df04[3]+df04[4]+df04[5]+df04[6]
df04
# Out:
#              0         1      2         3         4         5         6  \
# 0     0.000000  0.000000  0.000  0.000000  0.000000  0.000000  0.000000
# 1     0.100000  0.100000  0.100  0.001063  0.000897  0.001063  0.000897
# 2     1.865000  0.591000  2.058  0.002754  0.002753  0.002754  0.002753
# 3     0.720000  3.516000  3.452  0.001353  0.002709  0.002710  0.001352
# 4     1.203000  4.352000  1.648  0.002003  0.002002  0.002610  0.002610
# ...        ...       ...    ...       ...       ...       ...       ...
# 4996  2.735916  2.636475  4.574  0.910949  0.910873  0.910977  0.910892
# 4997  1.655878  1.952060  2.880  0.913051  0.912970  0.913069  0.912987
# 4998  1.591194  1.911410  2.778  0.918065  0.917994  0.918081  0.918008
# 4999  0.507910  1.248769  1.037  0.913516  0.913442  0.913528  0.913451
# 5000  0.798073  1.420688  1.514  0.918514  0.918430  0.918551  0.918467
#
#              X
# 0     0.000000
# 1     0.003921
# 2     0.011014
# 3     0.008124
# 4     0.009225
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
df04.hist(bins=50, figsize=(20,15))
plt.show()

# %%
DF=df02
DF=DF.append(df04)
DF
# Out:
#              0         1      2         3         4         5         6  \
# 0     0.000000  0.000000  0.000  0.000000  0.000000  0.000000  0.000000
# 1     0.100000  0.100000  0.100  0.000828  0.000730  0.001324  0.001117
# 2     1.290000  1.279000  2.836  0.032657  0.034125  0.052215  0.052215
# 3     3.610000  3.381000  1.039  0.004852  0.005427  0.007757  0.008304
# 4     3.695000  1.450000  3.930  0.005059  0.005287  0.008089  0.008089
# ...        ...       ...    ...       ...       ...       ...       ...
# 4996  2.735916  2.636475  4.574  0.910949  0.910873  0.910977  0.910892
# 4997  1.655878  1.952060  2.880  0.913051  0.912970  0.913069  0.912987
# 4998  1.591194  1.911410  2.778  0.918065  0.917994  0.918081  0.918008
# 4999  0.507910  1.248769  1.037  0.913516  0.913442  0.913528  0.913451
# 5000  0.798073  1.420688  1.514  0.918514  0.918430  0.918551  0.918467
#
#              X
# 0     0.000000
# 1     0.003999
# 2     0.171212
# 3     0.026339
# 4     0.026524
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
DF.hist(bins=50, figsize=(20,15))
plt.show()

# %%
newdf = DF.copy()

# %%
# Shuffling a Pandas dataframe with .shuffle()
newdf = newdf.sample(frac=1).reset_index()
print(newdf.head())
# Out:
#    index      0         1      2         3         4         5         6  \
# 0  10124  0.678  0.739000  0.791  0.003461  0.003616  0.005533  0.005533
# 1   4512  0.804  1.146116  4.424  0.002871  0.517205  0.791381  0.004590
# 2  18342  2.951  4.522000  3.085  0.006552  0.006847  0.032764  0.032764
# 3   1618  0.449  1.240574  0.838  0.067286  0.555547  0.850048  0.107582
# 4  11385  0.033  4.663000  4.127  0.000001  0.000666  0.001018  0.000002
#
#           X
# 0  0.018143
# 1  1.316048
# 2  0.078927
# 3  1.580464
# 4  0.001687

# %%
#Saving the data in CSV form
#newdf.to_csv(r'C:\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\data_N4.csv',  header=True)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
newdf.hist(bins=50, figsize=(20,15))
plt.show()

# %%
X = newdf[['p','q','d']].values
Y = newdf[['rig1','rig2','rig3','rig4','Order']].values

# %%
Y
# Out:
# array([[0.01238888, 0.0217551 , 0.02689149, 0.01600212, 0.07703758],
#        [0.00348684, 0.00364354, 0.00450378, 0.00450378, 0.01613794],
#        [0.00354352, 0.00370277, 0.00457699, 0.004577  , 0.01640029],
#        ...,
#        [0.00491739, 0.51592395, 0.63773378, 0.00635156, 1.16492668],
#        [0.01150416, 0.50553501, 0.62489202, 0.01485937, 1.15679055],
#        [0.01231314, 0.01286649, 0.62064186, 0.6206428 , 1.26646429]])
