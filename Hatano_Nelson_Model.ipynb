# %%
from scipy import linalg
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
N=7
X_data=np.array([[N,0,0]])
Y_data=np.array([np.zeros(N)])

H=np.zeros((N,N))
rig=np.zeros(N)


for m in range(20000):
    t1=0.000001 + round(np.random.uniform(0,1), 5) /100000
    t2=  round(np.random.uniform(0,1), 5)# /100000  
    for i in range(N):
        for j in range(N):
            if i==j+1:
                H[i,j]=t1
            if i==j-1:
                H[i,j]=t2
    Evals,LEvecs,REvecs=linalg.eig(H,left=True, right=True)            
    for i in range(N):
        rig[i]=(np.dot(np.conjugate(LEvecs[:,i]),REvecs[:,i]))/(np.dot(np.conjugate(REvecs[:,i]),REvecs[:,i]))
    arr_x=np.array([[N,t1,t2]])
   # arr_y= np.array([rig])
    arr_y= np.array([-np.log(rig)])
    X_data=np.append(X_data,arr_x,axis=0)
    Y_data=np.append(Y_data,arr_y,axis=0)
    

Data=np.concatenate((X_data,Y_data),axis=1)
df = pd.DataFrame(Data)
df
# Out:
#          0         1        2          3          4          5          6  \
# 0      7.0  0.000000  0.00000   0.000000   0.000000   0.000000   0.000000
# 1      7.0  0.000010  0.79250  30.548991  31.776920  32.311703  32.470042
# 2      7.0  0.000007  0.23368  27.870257  29.098161  29.632918  29.791247
# 3      7.0  0.000008  0.67100  30.547549  31.775478  32.310261  32.468600
# 4      7.0  0.000003  0.20337  30.288261  31.516189  32.050970  32.209309
# ...    ...       ...      ...        ...        ...        ...        ...
# 19996  7.0  0.000003  0.38269  32.148112  33.376049  33.910839  34.069181
# 19997  7.0  0.000002  0.49422  33.867658  35.095599  35.630393  35.788738
# 19998  7.0  0.000002  0.32477  32.946077  34.174016  34.708808  34.867152
# 19999  7.0  0.000003  0.72513  34.412540  35.640482  36.175278  36.333623
# 20000  7.0  0.000001  0.36548  34.244427  35.472369  36.007164  36.165509
#
#                7          8          9
# 0       0.000000   0.000000   0.000000
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
A=df.drop(df[(df[5]<31) | (df[5]>34)].index)
# %matplotlib inline 
import matplotlib.pyplot as plt
A.hist(bins=50, figsize=(20,15))
plt.show()

# %%
A = A.drop(A.index[5000:])
A=A.reset_index(drop=True)
A
# Out:
#         0         1        2          3          4          5          6  \
# 0     7.0  0.000010  0.79250  30.548991  31.776920  32.311703  32.470042
# 1     7.0  0.000008  0.67100  30.547549  31.775478  32.310261  32.468600
# 2     7.0  0.000003  0.20337  30.288261  31.516189  32.050970  32.209309
# 3     7.0  0.000010  0.60287  29.682275  30.910198  31.444974  31.603312
# 4     7.0  0.000010  0.95260  31.082505  32.310437  32.845222  33.003563
# ...   ...       ...      ...        ...        ...        ...        ...
# 4995  7.0  0.000006  0.86632  32.132374  33.360311  33.895101  34.053443
# 4996  7.0  0.000003  0.30785  31.339163  32.567097  33.101883  33.260225
# 4997  7.0  0.000010  0.67915  30.058364  31.286290  31.821069  31.979408
# 4998  7.0  0.000009  0.58422  30.046947  31.274873  31.809652  31.967990
# 4999  7.0  0.000005  0.35010  30.040861  31.268787  31.803566  31.961904
#
#               7          8          9
# 0     30.548991  31.776920  32.311703
# ...

# %%
N=7
X_data=np.array([[N,0,0]])
Y_data=np.array([np.zeros(N)])

H=np.zeros((N,N))
rig=np.zeros(N)


for m in range(20000):
    t2=0.000001 + round(np.random.uniform(0,1), 5) /100000
    t1=  round(np.random.uniform(0,1), 5)# /100000  
    for i in range(N):
        for j in range(N):
            if i==j+1:
                H[i,j]=t1
            if i==j-1:
                H[i,j]=t2
    Evals,LEvecs,REvecs=linalg.eig(H,left=True, right=True)            
    for i in range(N):
        rig[i]=(np.dot(np.conjugate(LEvecs[:,i]),REvecs[:,i]))/(np.dot(np.conjugate(REvecs[:,i]),REvecs[:,i]))
    arr_x=np.array([[N,t1,t2]])
   # arr_y= np.array([rig])
    arr_y= np.array([-np.log(rig)])
    X_data=np.append(X_data,arr_x,axis=0)
    Y_data=np.append(Y_data,arr_y,axis=0)
    

Data=np.concatenate((X_data,Y_data),axis=1)
df = pd.DataFrame(Data)
df
# Out:
#          0        1         2          3          4          5          6  \
# 0      7.0  0.00000  0.000000   0.000000   0.000000   0.000000   0.000000
# 1      7.0  0.82740  0.000011  30.415169  31.643097  32.177879  32.336218
# 2      7.0  0.20097  0.000008  27.263612  28.491506  29.026253  29.184578
# 3      7.0  0.11460  0.000003  28.240499  29.468408  30.003170  30.161501
# 4      7.0  0.69528  0.000009  30.330826  31.558754  32.093535  32.251874
# ...    ...      ...       ...        ...        ...        ...        ...
# 19996  7.0  0.58588  0.000002  34.394620  35.622563  36.157358  36.315703
# 19997  7.0  0.33010  0.000005  29.738303  30.966227  31.501003  31.659341
# 19998  7.0  0.34619  0.000002  33.241886  34.469826  35.004619  35.162963
# 19999  7.0  0.09595  0.000007  25.421580  26.649429  27.184131  27.342438
# 20000  7.0  0.44704  0.000004  31.754026  32.981961  33.516749  33.675092
#
#                7          8          9
# 0       0.000000   0.000000   0.000000
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
B=df.drop(df[(df[5]<31) | (df[5]>34)].index)
# %matplotlib inline 
import matplotlib.pyplot as plt
B.hist(bins=50, figsize=(20,15))
plt.show()

# %%
B = B.drop(B.index[5000:])
B=B.reset_index(drop=True)
B
# Out:
#         0        1         2          3          4          5          6  \
# 0     7.0  0.82740  0.000011  30.415169  31.643097  32.177879  32.336218
# 1     7.0  0.69528  0.000009  30.330826  31.558754  32.093535  32.251874
# 2     7.0  0.13461  0.000002  29.485324  30.713246  31.248020  31.406357
# 3     7.0  0.66439  0.000007  31.263243  32.491176  33.025962  33.184303
# 4     7.0  0.44363  0.000006  30.530986  31.758916  32.293698  32.452038
# ...   ...      ...       ...        ...        ...        ...        ...
# 4995  7.0  0.43540  0.000007  29.996635  31.224561  31.759339  31.917678
# 4996  7.0  0.84043  0.000008  31.197454  32.425387  32.960173  33.118514
# 4997  7.0  0.79112  0.000008  31.333790  32.561723  33.096510  33.254851
# 4998  7.0  0.69487  0.000008  30.739632  31.967563  32.502346  32.660686
# 4999  7.0  0.38182  0.000004  31.201946  32.429879  32.964665  33.123006
#
#               7          8          9
# 0     30.415169  31.643097  32.177879
# ...

# %%
N=7
X_data=np.array([[N,0,0]])
Y_data=np.array([np.zeros(N)])

H=np.zeros((N,N))
rig=np.zeros(N)


for m in range(40000):
    t1=0.000001 + round(np.random.uniform(0,1), 5) #/100000
    t2=  round(np.random.uniform(0,1), 5)# /100000  
    for i in range(N):
        for j in range(N):
            if i==j+1:
                H[i,j]=t1
            if i==j-1:
                H[i,j]=t2
    Evals,LEvecs,REvecs=linalg.eig(H,left=True, right=True)            
    for i in range(N):
        rig[i]=(np.dot(np.conjugate(LEvecs[:,i]),REvecs[:,i]))/(np.dot(np.conjugate(REvecs[:,i]),REvecs[:,i]))
    arr_x=np.array([[N,t1,t2]])
   # arr_y= np.array([rig])
    arr_y= np.array([-np.log(rig)])
    X_data=np.append(X_data,arr_x,axis=0)
    Y_data=np.append(Y_data,arr_y,axis=0)
    

Data=np.concatenate((X_data,Y_data),axis=1)
df = pd.DataFrame(Data)
df
# Out:
#          0         1        2          3          4          5          6  \
# 0      7.0  0.000000  0.00000   0.000000   0.000000   0.000000   0.000000
# 1      7.0  0.739981  0.06130   4.448067   5.552314   5.977045   6.093126
# 2      7.0  0.199611  0.36345   0.361105   0.680944   0.747796   0.762218
# 3      7.0  0.003761  0.82268  12.871867  14.093328  14.621684  14.777374
# 4      7.0  0.434401  0.18723   0.689824   1.196134   1.316150   1.342914
# ...    ...       ...      ...        ...        ...        ...        ...
# 39996  7.0  0.150291  0.93734   2.731944   3.710059   4.045133   4.131168
# 39997  7.0  0.466431  0.66676   0.131375   0.267937   0.293363   0.298711
# 39998  7.0  0.356861  0.02606   4.792833   5.912386   6.349401   6.469887
# 39999  7.0  0.156601  0.53399   1.375448   2.122297   2.333641   2.383609
# 40000  7.0  0.344831  0.20665   0.266122   0.517061   0.567237   0.577951
#
#                7          8          9
# 0       0.000000   0.000000   0.000000
# ...

# %%
C=df.drop(df[(df[5]>1)].index)
#C=df
# %matplotlib inline 
import matplotlib.pyplot as plt
C.hist(bins=50, figsize=(20,15))
plt.show()

# %%
C = C.drop(C.index[20000:])
C
# Out:
#          0         1        2         3         4         5         6  \
# 0      7.0  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# 2      7.0  0.199611  0.36345  0.361105  0.680944  0.747796  0.762218
# 5      7.0  0.886271  0.46218  0.423605  0.784491  0.861984  0.878812
# 7      7.0  0.580851  0.59993  0.001089  0.002349  0.002565  0.002610
# 10     7.0  0.196181  0.34452  0.320145  0.611303  0.671040  0.320145
# ...    ...       ...      ...       ...       ...       ...       ...
# 39378  7.0  0.767011  0.73424  0.001988  0.004285  0.004680  0.004761
# 39379  7.0  0.405171  0.62773  0.195935  0.390040  0.427488  0.195935
# 39385  7.0  0.697631  0.46786  0.163701  0.329760  0.361243  0.367890
# 39386  7.0  0.854851  0.77860  0.009095  0.019539  0.021342  0.021716
# 39389  7.0  0.746401  0.36746  0.498191  0.904235  0.994089  1.013752
#
#               7         8         9
# 0      0.000000  0.000000  0.000000
# 2      0.361105  0.680944  0.747796
# ...

# %%
temp_df=A
temp_df=temp_df.append(B)
temp_df=temp_df.append(C)
temp_df.describe()
# Out:
#              0             1             2             3             4  \
# count  30000.0  30000.000000  30000.000000  30000.000000  30000.000000
# mean       7.0      0.487031      0.486530     10.352829     10.850663
# std        0.0      0.305881      0.305437     14.449652     14.966742
# min        7.0      0.000000      0.000000      0.000000      0.000000
# 25%        7.0      0.259451      0.259593      0.047608      0.100520
# 50%        7.0      0.519190      0.519335      0.234545      0.460596
# 75%        7.0      0.737279      0.736390     30.119833     31.347759
# max        7.0      1.000001      0.999890     32.236390     33.464327
#
#                   5             6             7             8             9
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      11.046622     11.081468     10.374547     10.850663     11.046622
# std       15.206507     15.293686     14.434678     14.966742     15.206507
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
temp_df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#DF3=temp_df




#DF4=temp_df


#DF5=temp_df



#DF6=temp_df

DF7=temp_df

#DF=df
#DF=DF.append(df)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
DF7.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#********************************************For N=3
# DF3[3]=DF3[3]/DF3[3].max()
# DF3[4]=DF3[4]/DF3[4].max()
# DF3[5]=DF3[5]/DF3[5].max()

# DF3["X"]=DF3[3]+DF3[4]+DF3[5]   
##**************************************************For N=4*******************************

# DF4[3]=DF4[3]/DF4[3].max()
# DF4[4]=DF4[4]/DF4[4].max()
# DF4[5]=DF4[5]/DF4[5].max()
# DF4[6]=DF4[6]/DF4[6].max()    
 
# DF4["X"]=DF4[3]+DF4[4]+DF4[5]+DF4[6]
##**************************************************For N=5*******************************

# DF5[3]=DF5[3]/DF5[3].max()
# DF5[4]=DF5[4]/DF5[4].max()
# DF5[5]=DF5[5]/DF5[5].max()

# DF5[6]=DF5[6]/DF5[6].max()    
# DF5[7]=DF5[7]/DF5[7].max()    
# DF5["X"]=DF5[3]+DF5[4]+DF5[5]+DF5[6]+DF5[7] 


##**************************************************For N=6******************************
# DF6[3]=DF6[3]/DF6[3].max()
# DF6[4]=DF6[4]/DF6[4].max()
# DF6[5]=DF6[5]/DF6[5].max()
# DF6[6]=DF6[6]/DF6[6].max()    
# DF6[7]=DF6[7]/DF6[7].max()   
# DF6[8]=DF6[8]/DF6[8].max()    

# DF6["X"]=DF6[3]+DF6[4]+DF6[5]+DF6[6]+DF6[7]+DF6[8]

##**************************************************For N=7*******************************
DF7[3]=DF7[3]/DF7[3].max()
DF7[4]=DF7[4]/DF7[4].max()
DF7[5]=DF7[5]/DF7[5].max()

DF7[6]=DF7[6]/DF7[6].max()    
DF7[7]=DF7[7]/DF7[7].max()   
DF7[8]=DF7[8]/DF7[8].max()    
DF7[9]=DF7[9]/DF7[9].max() 
DF7["X"]=DF7[3]+DF7[4]+DF7[5]+DF7[6]+DF7[7]+DF7[8]+DF7[9]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
DF7.hist(bins=50, figsize=(20,15))
plt.show()

# %%
#DF3.to_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF3')

#DF4.to_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF4')

#DF6.to_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF6')

#DF7.to_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF7')

# %%
import pandas as pd

# %%
DF3=pd.read_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF3')
DF3
# Out:
#        Unnamed: 0    0         1        2         3         4         5  \
# 0               0  3.0  0.000007  0.58527  0.904444  0.910108  0.904444
# 1               1  3.0  0.000005  0.75321  0.965793  0.967821  0.965793
# 2               2  3.0  0.000010  0.54036  0.867628  0.875473  0.867628
# 3               3  3.0  0.000008  0.43355  0.865372  0.873351  0.865372
# 4               4  3.0  0.000009  0.51160  0.864455  0.872488  0.864455
# ...           ...  ...       ...      ...       ...       ...       ...
# 29995       22533  3.0  0.437071  0.22494  0.009850  0.017626  0.009850
# 29996       22534  3.0  0.981061  0.64251  0.004042  0.007442  0.004042
# 29997       22535  3.0  0.612721  0.96916  0.004737  0.008692  0.004737
# 29998       22536  3.0  0.387301  0.70477  0.008027  0.014490  0.008027
# 29999       22537  3.0  0.462201  0.34737  0.001848  0.003442  0.001848
#
#               X
# 0      2.718996
# 1      2.899406
# 2      2.610730
# 3      2.604095
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
DF3.hist(bins=50, figsize=(20,15))
plt.show()

# %%
DF7=pd.read_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF7')
DF7
# Out:
#        Unnamed: 0    0         1        2         3         4         5  \
# 0               0  7.0  0.000010  0.79250  0.947655  0.949576  0.950369
# 1               1  7.0  0.000008  0.67100  0.947611  0.949533  0.950326
# 2               2  7.0  0.000003  0.20337  0.939567  0.941785  0.942700
# 3               3  7.0  0.000010  0.60287  0.920769  0.923676  0.924876
# 4               4  7.0  0.000010  0.95260  0.964206  0.965519  0.966061
# ...           ...  ...       ...      ...       ...       ...       ...
# 29995       39378  7.0  0.767011  0.73424  0.000062  0.000128  0.000138
# 29996       39379  7.0  0.405171  0.62773  0.006078  0.011655  0.012574
# 29997       39385  7.0  0.697631  0.46786  0.005078  0.009854  0.010625
# 29998       39386  7.0  0.854851  0.77860  0.000282  0.000584  0.000628
# 29999       39389  7.0  0.746401  0.36746  0.015454  0.027021  0.029239
#
#               6         7         8         9         X
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
DF7.hist(bins=50, figsize=(20,15))
plt.show()

# %%
DF=DF3
DF=DF.append(DF7)
DF
# Out:
#        Unnamed: 0    0         1        2         3         4         5  \
# 0               0  3.0  0.000007  0.58527  0.904444  0.910108  0.904444
# 1               1  3.0  0.000005  0.75321  0.965793  0.967821  0.965793
# 2               2  3.0  0.000010  0.54036  0.867628  0.875473  0.867628
# 3               3  3.0  0.000008  0.43355  0.865372  0.873351  0.865372
# 4               4  3.0  0.000009  0.51160  0.864455  0.872488  0.864455
# ...           ...  ...       ...      ...       ...       ...       ...
# 29995       39378  7.0  0.767011  0.73424  0.000062  0.000128  0.000138
# 29996       39379  7.0  0.405171  0.62773  0.006078  0.011655  0.012574
# 29997       39385  7.0  0.697631  0.46786  0.005078  0.009854  0.010625
# 29998       39386  7.0  0.854851  0.77860  0.000282  0.000584  0.000628
# 29999       39389  7.0  0.746401  0.36746  0.015454  0.027021  0.029239
#
#               X         6         7         8         9
# ...

# %%
DF = DF.sample(frac=1).reset_index(drop=True)
DF
# Out:
#        Unnamed: 0    0         1         2         3         4         5  \
# 0             507  3.0  0.668180  0.000005  0.945982  0.949184  0.945982
# 1            1019  3.0  0.000005  0.908930  0.974453  0.975968  0.974453
# 2           38529  7.0  0.419601  0.701800  0.008328  0.015575  0.016819
# 3           13625  3.0  0.214911  0.373830  0.006878  0.012486  0.006878
# 4            4455  7.0  0.000007  0.669060  0.962674  0.964043  0.964609
# ...           ...  ...       ...       ...       ...       ...       ...
# 59995        3560  7.0  0.000008  0.726820  0.962583  0.963956  0.964523
# 59996        7576  3.0  0.862491  0.749050  0.000452  0.000848  0.000452
# 59997        5316  3.0  0.931301  0.416520  0.014336  0.025132  0.014336
# 59998       18591  3.0  0.604391  0.142610  0.043777  0.068862  0.043777
# 59999        2765  7.0  0.254140  0.000003  0.958792  0.960304  0.960928
#
#               X         6         7         8         9
# ...

# %%
DF=DF.reset_index(drop=True)
DF= DF.drop(DF.columns[0], axis=1)
DF
# Out:
#          0         1         2         3         4         5         X  \
# 0      3.0  0.668180  0.000005  0.945982  0.949184  0.945982  2.841148
# 1      3.0  0.000005  0.908930  0.974453  0.975968  0.974453  2.924875
# 2      7.0  0.419601  0.701800  0.008328  0.015575  0.016819  0.099050
# 3      3.0  0.214911  0.373830  0.006878  0.012486  0.006878  0.026242
# 4      7.0  0.000007  0.669060  0.962674  0.964043  0.964609  6.747423
# ...    ...       ...       ...       ...       ...       ...       ...
# 59995  7.0  0.000008  0.726820  0.962583  0.963956  0.964523  6.746813
# 59996  3.0  0.862491  0.749050  0.000452  0.000848  0.000452  0.001751
# 59997  3.0  0.931301  0.416520  0.014336  0.025132  0.014336  0.053803
# 59998  3.0  0.604391  0.142610  0.043777  0.068862  0.043777  0.156416
# 59999  7.0  0.254140  0.000003  0.958792  0.960304  0.960928  6.721159
#
#               6         7         8         9
# 0           NaN       NaN       NaN       NaN
# ...

# %%
fdf=DF.iloc[:, [0,1,2,6]].copy()
fdf
# Out:
#          0         1         2         X
# 0      3.0  0.668180  0.000005  2.841148
# 1      3.0  0.000005  0.908930  2.924875
# 2      7.0  0.419601  0.701800  0.099050
# 3      3.0  0.214911  0.373830  0.026242
# 4      7.0  0.000007  0.669060  6.747423
# ...    ...       ...       ...       ...
# 59995  7.0  0.000008  0.726820  6.746813
# 59996  3.0  0.862491  0.749050  0.001751
# 59997  3.0  0.931301  0.416520  0.053803
# 59998  3.0  0.604391  0.142610  0.156416
# 59999  7.0  0.254140  0.000003  6.721159
#
# [60000 rows x 4 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
fdf.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# ffdf=fdf.drop(fdf[(fdf['X']<6) & (fdf['X']>3)].index)
# ffdf

# %%
fdf
# Out:
#          0         1         2         X
# 0      3.0  0.668180  0.000005  2.841148
# 1      3.0  0.000005  0.908930  2.924875
# 2      7.0  0.419601  0.701800  0.099050
# 3      3.0  0.214911  0.373830  0.026242
# 4      7.0  0.000007  0.669060  6.747423
# ...    ...       ...       ...       ...
# 59995  7.0  0.000008  0.726820  6.746813
# 59996  3.0  0.862491  0.749050  0.001751
# 59997  3.0  0.931301  0.416520  0.053803
# 59998  3.0  0.604391  0.142610  0.156416
# 59999  7.0  0.254140  0.000003  6.721159
#
# [60000 rows x 4 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
fdf.hist(bins=50, figsize=(20,15))
plt.show()

# %%
fdf.to_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF37')

# %%
#************************************************* Caution: NETWORK  at WORK *************************************************#

# %%
import pandas as pd

# %%
fdf=pd.read_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF37')
fdf
# Out:
#        Unnamed: 0    0         1         2         X
# 0               0  3.0  0.668180  0.000005  2.841148
# 1               1  3.0  0.000005  0.908930  2.924875
# 2               2  7.0  0.419601  0.701800  0.099050
# 3               3  3.0  0.214911  0.373830  0.026242
# 4               4  7.0  0.000007  0.669060  6.747423
# ...           ...  ...       ...       ...       ...
# 59995       59995  7.0  0.000008  0.726820  6.746813
# 59996       59996  3.0  0.862491  0.749050  0.001751
# 59997       59997  3.0  0.931301  0.416520  0.053803
# 59998       59998  3.0  0.604391  0.142610  0.156416
# 59999       59999  7.0  0.254140  0.000003  6.721159
#
# [60000 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
import datetime

# %%
train, test = train_test_split( fdf, test_size=0.1, random_state=4)

X_train = train[['0','1','2']].values
Y_train = train[['X']].values

X_test = test[['0','1','2']].values
Y_test = test[['X']].values

# %%
Y_train.shape
# Out:
# (54000, 1)

# %%
X_test
# Out:
# array([[3.00000e+00, 4.29880e-06, 5.45980e-01],
#        [3.00000e+00, 2.55151e-01, 6.13420e-01],
#        [3.00000e+00, 9.51830e-06, 7.79540e-01],
#        ...,
#        [3.00000e+00, 2.93541e-01, 6.82720e-01],
#        [3.00000e+00, 3.54410e-06, 2.44430e-01],
#        [3.00000e+00, 8.85190e-06, 4.85290e-01]])

# %%
Y_test
# Out:
# array([[2.83068281],
#        [0.06330114],
#        [2.71337697],
#        ...,
#        [0.0588846 ],
#        [2.6674335 ],
#        [2.60606719]])

# %%
# keras:
from tensorflow.keras import Sequential # Sequential is the neural-network class
from tensorflow.keras.layers import Dense # Dense is the standard network layer
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
import datetime

# %%
################# Building the Neural_Network


Net=Sequential() # creating a neural network!
Net.add(Dense(12,input_shape=(3,),activation="relu")) # first hidden layer: 20 neurons (and 1 input neuron!)
#Net.add(Dense(50,activation="relu")) # second hidden layer: 10 neurons
#Net.add(Dense(100,activation="relu")) # second hidden layer: 10 neurons
Net.add(Dense(4,activation="relu"))
Net.add(Dense(1,activation="linear")) # output layer: 1 neuron


# Compile network: (randomly initialize weights, choose advanced optimizer, set up everything!)
# Net.compile(loss='mean_squared_error',
#               optimizer=Adam(learning_rate=0.001)

 # adam is adaptive and works better than normal gradient descent
Net.compile(loss='mean_squared_error',
              optimizer='adam')

# %%
# Does the training
Net.fit(X_train, Y_train, epochs=200, batch_size=32, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# 1688/1688 [==============================] - 2s 769us/step - loss: 4.0380 - val_loss: 3.2880
# Epoch 2/200
# 1688/1688 [==============================] - 1s 722us/step - loss: 2.0448 - val_loss: 1.1278
# Epoch 3/200
# 1688/1688 [==============================] - 1s 749us/step - loss: 0.7704 - val_loss: 0.4785
# Epoch 4/200
# 1688/1688 [==============================] - 1s 719us/step - loss: 0.3331 - val_loss: 0.2283
# Epoch 5/200
# 1688/1688 [==============================] - 1s 718us/step - loss: 0.1691 - val_loss: 0.1351
# Epoch 6/200
# 1688/1688 [==============================] - 1s 731us/step - loss: 0.1000 - val_loss: 0.0918
# Epoch 7/200
# 1688/1688 [==============================] - 1s 727us/step - loss: 0.0662 - val_loss: 0.0556
# Epoch 8/200
# 1688/1688 [==============================] - 1s 729us/step - loss: 0.0462 - val_loss: 0.0352
# Epoch 9/200
# 1688/1688 [==============================] - 1s 751us/step - loss: 0.0361 - val_loss: 0.0272
# Epoch 10/200
# ...

# %%
History=Net.history.history
#History

# %%
Net.save(r"\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\EP_ML\Model_Nsite.h5")

# %%
# log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

# Net.fit(x=X_train, 
#           y=Y_train, 
#           epochs=20, 
#           validation_data=(X_test, Y_test), 
#           callbacks=[tensorboard_callback])

# %%
pd.DataFrame(Net.history.history).plot(figsize=(8, 6))
plt.grid(True)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.legend(fontsize=25)
plt.ylabel('MSE Loss', fontsize=25)
plt.xlabel('Epoch', fontsize=25)
#plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
# plt.show()
plt.savefig(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\EP_ML\Loss_Nsite.png', bbox_inches='tight',dpi=600)

# %%
plt.figure(figsize=(8, 6))
plt.grid(True)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
train_loss = History['loss']
val_loss = History['val_loss']

plt.scatter(range(len(train_loss)), train_loss, label='Training set',s=5)
plt.scatter(range(len(val_loss)), val_loss, label='Validation set',s=5)
plt.ylabel('MSE Loss', fontsize=25)
plt.xlabel('Epoch', fontsize=25)
plt.legend(fontsize=25)
#plt.show()
plt.savefig(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\EP_ML\loss_NsiteS.png', bbox_inches='tight',dpi=600)

# %%
Net.predict([[4,0.001000,0.95100000]])
# Out:
# 1/1 [==============================] - 0s 73ms/step
# array([[3.8169653]], dtype=float32)

# %%
####################### Totoal No of parameters to tune
Net.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 12)                48
#
#  dense_1 (Dense)             (None, 4)                 52
#
#  dense_2 (Dense)             (None, 1)                 5
#
# ...
# Total params: 105
# Trainable params: 105
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error

# %%
Y_pred = Net.predict(X_test)
Y_pred
# Out:
# 188/188 [==============================] - 0s 742us/step
# array([[2.7255435 ],
#        [0.08123186],
#        [2.7960439 ],
#        ...,
#        [0.08270004],
#        [2.6344202 ],
#        [2.7071247 ]], dtype=float32)

# %%
import numpy as np

# %%
print("R^2 : ", r2_score(Y_test, Y_pred))
print("MAE :", mean_absolute_error(Y_test,Y_pred))
print("RMSE:",np.sqrt(mean_squared_error(Y_test, Y_pred)))
# Out:
# R^2 :  0.9987764029285446
# MAE : 0.05700747686990091
# RMSE: 0.08761521633984838

# %%
N, bins, patches = plt.hist(Y_pred,bins=100)

plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("SPR",fontsize=25)
plt.ylabel("counts",fontsize=25)
plt.grid()
plt.savefig(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\EP_ML\pred_HN.png', bbox_inches='tight',dpi=600)

# %%
N, bins, patches = plt.hist(Y_test,bins=100, label='x')

plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("SPR",fontsize=25)
plt.ylabel("counts",fontsize=25)
plt.grid()
plt.savefig(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\EP_ML\actual_HN.png', bbox_inches='tight',dpi=600)

# %%
new_data = np.column_stack((X_test, Y_pred))

# %%
pred=pd.DataFrame(new_data)

# %%
A_test = test.reset_index(drop=True)
A_test = A_test.drop(test.columns[0], axis=1)
A_test
# Out:
#         0         1        2         X
# 0     3.0  0.000004  0.54598  2.830683
# 1     3.0  0.255151  0.61342  0.063301
# 2     3.0  0.000010  0.77954  2.713377
# 3     3.0  0.147301  0.95958  0.243608
# 4     3.0  0.496451  0.56759  0.001579
# ...   ...       ...      ...       ...
# 5995  3.0  0.000008  0.29530  2.511514
# 5996  7.0  0.472061  0.58261  0.018060
# 5997  3.0  0.293541  0.68272  0.058885
# 5998  3.0  0.000004  0.24443  2.667433
# 5999  3.0  0.000009  0.48529  2.606067
#
# [6000 rows x 4 columns]

# %%
B_pred=pred
B_pred
# Out:
#         0         1        2         3
# 0     3.0  0.000004  0.54598  2.725543
# 1     3.0  0.255151  0.61342  0.081232
# 2     3.0  0.000010  0.77954  2.796044
# 3     3.0  0.147301  0.95958  0.198011
# 4     3.0  0.496451  0.56759 -0.019380
# ...   ...       ...      ...       ...
# 5995  3.0  0.000008  0.29530  2.649725
# 5996  7.0  0.472061  0.58261  0.023109
# 5997  3.0  0.293541  0.68272  0.082700
# 5998  3.0  0.000004  0.24443  2.634420
# 5999  3.0  0.000009  0.48529  2.707125
#
# [6000 rows x 4 columns]

# %%
def SPR(value):
    if value < 1:
        return 0
    if 2 <= value < 3:
        return 3
    if 3<= value < 4:
        return 4
    if 4<= value < 5:
        return 5
    if 5<= value < 6:
        return 6
    if 6 <= value <7:
        return 7

A_test['SPR'] = A_test['X'].map(SPR)
A_test
# Out:
#         0         1        2         X  SPR
# 0     3.0  0.000004  0.54598  2.830683    3
# 1     3.0  0.255151  0.61342  0.063301    0
# 2     3.0  0.000010  0.77954  2.713377    3
# 3     3.0  0.147301  0.95958  0.243608    0
# 4     3.0  0.496451  0.56759  0.001579    0
# ...   ...       ...      ...       ...  ...
# 5995  3.0  0.000008  0.29530  2.511514    3
# 5996  7.0  0.472061  0.58261  0.018060    0
# 5997  3.0  0.293541  0.68272  0.058885    0
# 5998  3.0  0.000004  0.24443  2.667433    3
# 5999  3.0  0.000009  0.48529  2.606067    3
#
# [6000 rows x 5 columns]

# %%
B_pred['SPR'] = B_pred[3].map(SPR)
B_pred
# Out:
#         0         1        2         3  SPR
# 0     3.0  0.000004  0.54598  2.725543    3
# 1     3.0  0.255151  0.61342  0.081232    0
# 2     3.0  0.000010  0.77954  2.796044    3
# 3     3.0  0.147301  0.95958  0.198011    0
# 4     3.0  0.496451  0.56759 -0.019380    0
# ...   ...       ...      ...       ...  ...
# 5995  3.0  0.000008  0.29530  2.649725    3
# 5996  7.0  0.472061  0.58261  0.023109    0
# 5997  3.0  0.293541  0.68272  0.082700    0
# 5998  3.0  0.000004  0.24443  2.634420    3
# 5999  3.0  0.000009  0.48529  2.707125    3
#
# [6000 rows x 5 columns]

# %%
count_A_test = (A_test.iloc[:,4] == 0).sum()
count_A_test
# Out:
# 3953

# %%
count_B_pred = (B_pred.iloc[:,4] == 0).sum()
count_B_pred
# Out:
# 3953

# %%
# mask_A = A_test.iloc[:, 4] == 7
# mask_B = B_pred.iloc[:, 4] == 7

# # filter the rows using the masks
# rows_A = A_test[mask_A]
# rows_B = B_pred[mask_B]

# # print the rows
# print(rows_A)
# print(rows_B)

# %%
# uncommon_rows = pd.concat([A_test[~A_test.isin(B_pred)].dropna(), B_pred[~B_pred.isin(A_test)].dropna()])
# uncommon_rows = uncommon_rows[uncommon_rows.iloc[:, 4] == 7]
# print(uncommon_rows)
# Out:
# Empty DataFrame
# Columns: [0, 1, 2, X, SPR, 0, 1, 2, 3]
# Index: []

# %%
C3 = A_test.drop(A_test.columns[3], axis=1)
C3
# Out:
#         0         1        2  SPR
# 0     3.0  0.000004  0.54598    3
# 1     3.0  0.255151  0.61342    0
# 2     3.0  0.000010  0.77954    3
# 3     3.0  0.147301  0.95958    0
# 4     3.0  0.496451  0.56759    0
# ...   ...       ...      ...  ...
# 5995  3.0  0.000008  0.29530    3
# 5996  7.0  0.472061  0.58261    0
# 5997  3.0  0.293541  0.68272    0
# 5998  3.0  0.000004  0.24443    3
# 5999  3.0  0.000009  0.48529    3
#
# [6000 rows x 4 columns]

# %%
C4 = B_pred.drop(B_pred.columns[3], axis=1)
C4
# Out:
#         0         1        2  SPR
# 0     3.0  0.000004  0.54598    3
# 1     3.0  0.255151  0.61342    0
# 2     3.0  0.000010  0.77954    3
# 3     3.0  0.147301  0.95958    0
# 4     3.0  0.496451  0.56759    0
# ...   ...       ...      ...  ...
# 5995  3.0  0.000008  0.29530    3
# 5996  7.0  0.472061  0.58261    0
# 5997  3.0  0.293541  0.68272    0
# 5998  3.0  0.000004  0.24443    3
# 5999  3.0  0.000009  0.48529    3
#
# [6000 rows x 4 columns]

# %%
C4 = C4.rename(columns=dict(zip(C4.columns, C3.columns)))

# %%
C4
# Out:
#         0         1        2  SPR
# 0     3.0  0.000004  0.54598    3
# 1     3.0  0.255151  0.61342    0
# 2     3.0  0.000010  0.77954    3
# 3     3.0  0.147301  0.95958    0
# 4     3.0  0.496451  0.56759    0
# ...   ...       ...      ...  ...
# 5995  3.0  0.000008  0.29530    3
# 5996  7.0  0.472061  0.58261    0
# 5997  3.0  0.293541  0.68272    0
# 5998  3.0  0.000004  0.24443    3
# 5999  3.0  0.000009  0.48529    3
#
# [6000 rows x 4 columns]

# %%
C5=C3.compare(C4)
C5
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(C3.equals(C4))
# Out:
# True

# %%
C5
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
C5[C5.iloc[:,3]==3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26836/4252116824.py in <module>
# ----> 1 C5[C5.iloc[:,3]==3]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ...

# %%
C5[C5.iloc[:,0]==7].shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26836/3811255563.py in <module>
# ----> 1 C5[C5.iloc[:,0]==7].shape
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
#    1508             return self._getitem_lowerdim(tup)
#
# ...

# %%
(6000-16)/6000

# %%
DF4=pd.read_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF4')
DF4
# Out:
#       Unnamed: 0    0         1        2         3         4         5  \
# 0              0  4.0  0.000007  0.50958  0.926582  0.930737  0.926582
# 1              1  4.0  0.000008  0.54332  0.919503  0.924060  0.919503
# 2              2  4.0  0.000006  0.60987  0.947949  0.950896  0.947949
# 3              3  4.0  0.000009  0.95834  0.963376  0.965449  0.963376
# 4              4  4.0  0.000007  0.75173  0.966165  0.968080  0.966165
# ...          ...  ...       ...      ...       ...       ...       ...
# 9995        8543  4.0  0.645151  0.35624  0.008675  0.016283  0.008675
# 9996        8548  4.0  0.921111  0.87401  0.000069  0.000137  0.000069
# 9997        8551  4.0  0.540281  0.72940  0.002244  0.004402  0.002244
# 9998        8552  4.0  0.442721  0.66782  0.004194  0.008111  0.004194
# 9999        8554  4.0  0.357511  0.85759  0.018464  0.032747  0.018464
#
#              6         X
# 0     0.930737  3.714638
# 1     0.924060  3.687126
# 2     0.950896  3.797691
# ...

# %%
fdf=DF4.iloc[:, [1,2,3,8]].copy()
fdf
# Out:
#         0         1        2         X
# 0     4.0  0.000007  0.50958  3.714638
# 1     4.0  0.000008  0.54332  3.687126
# 2     4.0  0.000006  0.60987  3.797691
# 3     4.0  0.000009  0.95834  3.857651
# 4     4.0  0.000007  0.75173  3.868489
# ...   ...       ...      ...       ...
# 9995  4.0  0.645151  0.35624  0.049915
# 9996  4.0  0.921111  0.87401  0.000413
# 9997  4.0  0.540281  0.72940  0.013293
# 9998  4.0  0.442721  0.66782  0.024610
# 9999  4.0  0.357511  0.85759  0.102422
#
# [10000 rows x 4 columns]

# %%
# fdf=fdf.drop(fdf[(fdf['X']<3) & (fdf['X']>0.8)].index)

# %%
# train, test = train_test_split( fdf, test_size=0.99, random_state=4)

# X_train = train[['0','1','2']].values
# Y_train = train[['X']].values

# XDF4_test = test[['0','1','2']].values
# YDF4_test = test[['X']].values

# %%
XDF4_test = fdf.iloc[:, 0:3].values
YDF4_test = fdf.iloc[:, 3].values
XDF4_test
# Out:
# array([[4.00000e+00, 6.79400e-06, 5.09580e-01],
#        [4.00000e+00, 7.81330e-06, 5.43320e-01],
#        [4.00000e+00, 6.47050e-06, 6.09870e-01],
#        ...,
#        [4.00000e+00, 5.40281e-01, 7.29400e-01],
#        [4.00000e+00, 4.42721e-01, 6.67820e-01],
#        [4.00000e+00, 3.57511e-01, 8.57590e-01]])

# %%
N, bins, patches = plt.hist(YDF4_test,bins=100, label='x')
plt.xticks([1,2,3,4],fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("SPR",fontsize=25)
plt.ylabel("counts",fontsize=25)
plt.grid()
plt.savefig(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\EP_ML\actual_DF4.png', bbox_inches='tight',dpi=600)

# %%
YDF4_pred = Net.predict(XDF4_test)
# Out:
# 313/313 [==============================] - 0s 663us/step

# %%
N, bins, patches = plt.hist(YDF4_pred,bins=100, label='x')
plt.xticks([1,2,3,4],fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("SPR",fontsize=25)
plt.ylabel("counts",fontsize=25)
plt.grid()
plt.savefig(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\EP_ML\pred_DF4.png', bbox_inches='tight',dpi=600)

# %%
new_data = np.column_stack((XDF4_test, YDF4_pred))
pred=pd.DataFrame(new_data)
B_pred=pred
B_pred
# Out:
#         0         1        2         3
# 0     4.0  0.000007  0.50958  3.700199
# 1     4.0  0.000008  0.54332  3.710379
# 2     4.0  0.000006  0.60987  3.730514
# 3     4.0  0.000009  0.95834  3.835795
# 4     4.0  0.000007  0.75173  3.773386
# ...   ...       ...      ...       ...
# 9995  4.0  0.645151  0.35624  0.061312
# 9996  4.0  0.921111  0.87401 -0.031960
# 9997  4.0  0.540281  0.72940  0.009148
# 9998  4.0  0.442721  0.66782  0.031432
# 9999  4.0  0.357511  0.85759  0.105833
#
# [10000 rows x 4 columns]

# %%
new_data = np.column_stack((XDF4_test, YDF4_test))
A_test=pd.DataFrame(new_data)
A_test
# Out:
#         0         1        2         3
# 0     4.0  0.000007  0.50958  3.714638
# 1     4.0  0.000008  0.54332  3.687126
# 2     4.0  0.000006  0.60987  3.797691
# 3     4.0  0.000009  0.95834  3.857651
# 4     4.0  0.000007  0.75173  3.868489
# ...   ...       ...      ...       ...
# 9995  4.0  0.645151  0.35624  0.049915
# 9996  4.0  0.921111  0.87401  0.000413
# 9997  4.0  0.540281  0.72940  0.013293
# 9998  4.0  0.442721  0.66782  0.024610
# 9999  4.0  0.357511  0.85759  0.102422
#
# [10000 rows x 4 columns]

# %%
def SPR(value):
    if value < 1:
        return 0
    if 1 <= value<2:
        return 2
    if 2 <= value<3:
        return 3
    if 3 <= value<4:
        return 3
    if 4<= value<5:
        return 4

# %%
A_test['SPR'] = A_test[3].map(SPR)
A_test
# Out:
#         0         1        2         3  SPR
# 0     4.0  0.000007  0.50958  3.714638    3
# 1     4.0  0.000008  0.54332  3.687126    3
# 2     4.0  0.000006  0.60987  3.797691    3
# 3     4.0  0.000009  0.95834  3.857651    3
# 4     4.0  0.000007  0.75173  3.868489    3
# ...   ...       ...      ...       ...  ...
# 9995  4.0  0.645151  0.35624  0.049915    0
# 9996  4.0  0.921111  0.87401  0.000413    0
# 9997  4.0  0.540281  0.72940  0.013293    0
# 9998  4.0  0.442721  0.66782  0.024610    0
# 9999  4.0  0.357511  0.85759  0.102422    0
#
# [10000 rows x 5 columns]

# %%
B_pred['SPR'] = B_pred[3].map(SPR)
B_pred
# Out:
#         0         1        2         3  SPR
# 0     4.0  0.000007  0.50958  3.700199    3
# 1     4.0  0.000008  0.54332  3.710379    3
# 2     4.0  0.000006  0.60987  3.730514    3
# 3     4.0  0.000009  0.95834  3.835795    3
# 4     4.0  0.000007  0.75173  3.773386    3
# ...   ...       ...      ...       ...  ...
# 9995  4.0  0.645151  0.35624  0.061312    0
# 9996  4.0  0.921111  0.87401 -0.031960    0
# 9997  4.0  0.540281  0.72940  0.009148    0
# 9998  4.0  0.442721  0.66782  0.031432    0
# 9999  4.0  0.357511  0.85759  0.105833    0
#
# [10000 rows x 5 columns]

# %%
C3 = A_test.drop(A_test.columns[3], axis=1)
C3
# Out:
#         0         1        2  SPR
# 0     4.0  0.000007  0.50958    3
# 1     4.0  0.000008  0.54332    3
# 2     4.0  0.000006  0.60987    3
# 3     4.0  0.000009  0.95834    3
# 4     4.0  0.000007  0.75173    3
# ...   ...       ...      ...  ...
# 9995  4.0  0.645151  0.35624    0
# 9996  4.0  0.921111  0.87401    0
# 9997  4.0  0.540281  0.72940    0
# 9998  4.0  0.442721  0.66782    0
# 9999  4.0  0.357511  0.85759    0
#
# [10000 rows x 4 columns]

# %%
C4 = B_pred.drop(B_pred.columns[3], axis=1)
C4
# Out:
#         0         1        2  SPR
# 0     4.0  0.000007  0.50958    3
# 1     4.0  0.000008  0.54332    3
# 2     4.0  0.000006  0.60987    3
# 3     4.0  0.000009  0.95834    3
# 4     4.0  0.000007  0.75173    3
# ...   ...       ...      ...  ...
# 9995  4.0  0.645151  0.35624    0
# 9996  4.0  0.921111  0.87401    0
# 9997  4.0  0.540281  0.72940    0
# 9998  4.0  0.442721  0.66782    0
# 9999  4.0  0.357511  0.85759    0
#
# [10000 rows x 4 columns]

# %%
C4 = C4.rename(columns=dict(zip(C4.columns, C3.columns)))

# %%
C5=C3.compare(C4)
C5
# Out:
#       SPR
#      self other
# 352   4.0   3.0
# 3000  0.0   2.0

# %%
C5[C5.iloc[:,0]==1]
# Out:
# Empty DataFrame
# Columns: [(SPR, self), (SPR, other)]
# Index: []

# %%
DF4=pd.read_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF4')
DF4
# Out:
#       Unnamed: 0    0         1        2         3         4         5  \
# 0              0  4.0  0.000007  0.50958  0.926582  0.930737  0.926582
# 1              1  4.0  0.000008  0.54332  0.919503  0.924060  0.919503
# 2              2  4.0  0.000006  0.60987  0.947949  0.950896  0.947949
# 3              3  4.0  0.000009  0.95834  0.963376  0.965449  0.963376
# 4              4  4.0  0.000007  0.75173  0.966165  0.968080  0.966165
# ...          ...  ...       ...      ...       ...       ...       ...
# 9995        8543  4.0  0.645151  0.35624  0.008675  0.016283  0.008675
# 9996        8548  4.0  0.921111  0.87401  0.000069  0.000137  0.000069
# 9997        8551  4.0  0.540281  0.72940  0.002244  0.004402  0.002244
# 9998        8552  4.0  0.442721  0.66782  0.004194  0.008111  0.004194
# 9999        8554  4.0  0.357511  0.85759  0.018464  0.032747  0.018464
#
#              6         X
# 0     0.930737  3.714638
# 1     0.924060  3.687126
# 2     0.950896  3.797691
# ...

# %%
# DF5=pd.read_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF5')
# DF5

# %%
DF6=pd.read_csv(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\NN_data\HN_DF6')
DF6
# Out:
#       Unnamed: 0    0         1        2         3         4         5  \
# 0              0  6.0  0.000008  0.81621  0.994409  0.994651  0.994737
# 1              1  6.0  0.000004  0.32598  0.974218  0.975335  0.975729
# 2              2  6.0  0.000008  0.56850  0.959487  0.961243  0.961862
# 3              3  6.0  0.000009  0.55192  0.943461  0.945911  0.946775
# 4              4  6.0  0.000010  0.83239  0.981438  0.982243  0.982526
# ...          ...  ...       ...      ...       ...       ...       ...
# 9995       12547  6.0  0.627101  0.85470  0.002916  0.005806  0.006208
# 9996       12548  6.0  0.114911  0.09566  0.001028  0.002091  0.002234
# 9997       12549  6.0  0.614581  0.54444  0.000450  0.000921  0.000984
# 9998       12551  6.0  0.223771  0.47553  0.016653  0.029353  0.031508
# 9999       12553  6.0  0.645421  0.35118  0.011019  0.020297  0.021763
#
#              6         7         8         X
# 0     0.994409  0.994737  0.994651  5.967595
# ...

# %%
TDF=DF4
TDF=TDF.append(DF6)
TDF
# Out:
#       Unnamed: 0    0         1        2         3         4         5  \
# 0              0  4.0  0.000007  0.50958  0.926582  0.930737  0.926582
# 1              1  4.0  0.000008  0.54332  0.919503  0.924060  0.919503
# 2              2  4.0  0.000006  0.60987  0.947949  0.950896  0.947949
# 3              3  4.0  0.000009  0.95834  0.963376  0.965449  0.963376
# 4              4  4.0  0.000007  0.75173  0.966165  0.968080  0.966165
# ...          ...  ...       ...      ...       ...       ...       ...
# 9995       12547  6.0  0.627101  0.85470  0.002916  0.005806  0.006208
# 9996       12548  6.0  0.114911  0.09566  0.001028  0.002091  0.002234
# 9997       12549  6.0  0.614581  0.54444  0.000450  0.000921  0.000984
# 9998       12551  6.0  0.223771  0.47553  0.016653  0.029353  0.031508
# 9999       12553  6.0  0.645421  0.35118  0.011019  0.020297  0.021763
#
#              6         X         7         8
# 0     0.930737  3.714638       NaN       NaN
# ...

# %%
fdf=TDF.iloc[:, [ 1,2,3,8]].copy()
fdf
# Out:
#         0         1        2         X
# 0     4.0  0.000007  0.50958  3.714638
# 1     4.0  0.000008  0.54332  3.687126
# 2     4.0  0.000006  0.60987  3.797691
# 3     4.0  0.000009  0.95834  3.857651
# 4     4.0  0.000007  0.75173  3.868489
# ...   ...       ...      ...       ...
# 9995  6.0  0.627101  0.85470  0.029860
# 9996  6.0  0.114911  0.09566  0.010783
# 9997  6.0  0.614581  0.54444  0.004709
# 9998  6.0  0.223771  0.47553  0.155028
# 9999  6.0  0.645421  0.35118  0.106159
#
# [20000 rows x 4 columns]

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
fdf.hist(bins=50, figsize=(20,15))
plt.show()

# %%
# fdf=fdf.drop(fdf[(fdf['X']<3) & (fdf['X']>0.5)].index)
# fdf=fdf.drop(fdf[(fdf['X']<5) & (fdf['X']>4)].index)

# %%
# train, test = train_test_split( fdf, test_size=0.99, random_state=4)

# X_train = train[['0','1','2']].values
# Y_train = train[['X']].values

# XDF5_test = test[['0','1','2']].values
# YDF5_test = test[['X']].values

# %%
XDF46_test = fdf.iloc[:, 0:3].values
YDF46_test = fdf.iloc[:, 3].values
XDF46_test
# Out:
# array([[4.00000e+00, 6.79400e-06, 5.09580e-01],
#        [4.00000e+00, 7.81330e-06, 5.43320e-01],
#        [4.00000e+00, 6.47050e-06, 6.09870e-01],
#        ...,
#        [6.00000e+00, 6.14581e-01, 5.44440e-01],
#        [6.00000e+00, 2.23771e-01, 4.75530e-01],
#        [6.00000e+00, 6.45421e-01, 3.51180e-01]])

# %%
N, bins, patches = plt.hist(YDF46_test,bins=100, label='x')
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("SPR",fontsize=25)
plt.ylabel("counts",fontsize=25)
plt.grid()
plt.savefig(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\EP_ML\actual_DF46.png', bbox_inches='tight',dpi=600)

# %%
YDF46_pred = Net.predict(XDF46_test)
# Out:
# 625/625 [==============================] - 0s 578us/step

# %%
N, bins, patches = plt.hist(YDF46_pred,bins=100, label='x')
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)
plt.xlabel("SPR",fontsize=25)
plt.ylabel("counts",fontsize=25)
plt.grid()
plt.savefig(r'\Users\iamaf\OneDrive\Desktop\OneDrive - Indian Institute of Science\reja_awadhesh\EP_ML\pred_DF46.png', bbox_inches='tight',dpi=600)

# %%
new_data = np.column_stack((XDF46_test, YDF46_pred))
pred=pd.DataFrame(new_data)
B_pred=pred
B_pred
# Out:
#          0         1        2         3
# 0      4.0  0.000007  0.50958  3.700199
# 1      4.0  0.000008  0.54332  3.710379
# 2      4.0  0.000006  0.60987  3.730514
# 3      4.0  0.000009  0.95834  3.835795
# 4      4.0  0.000007  0.75173  3.773386
# ...    ...       ...      ...       ...
# 19995  6.0  0.627101  0.85470  0.020017
# 19996  6.0  0.114911  0.09566  0.037846
# 19997  6.0  0.614581  0.54444  0.004970
# 19998  6.0  0.223771  0.47553  0.083453
# 19999  6.0  0.645421  0.35118  0.068538
#
# [20000 rows x 4 columns]

# %%
new_data = np.column_stack((XDF46_test, YDF46_test))
A_test=pd.DataFrame(new_data)
A_test
# Out:
#          0         1        2         3
# 0      4.0  0.000007  0.50958  3.714638
# 1      4.0  0.000008  0.54332  3.687126
# 2      4.0  0.000006  0.60987  3.797691
# 3      4.0  0.000009  0.95834  3.857651
# 4      4.0  0.000007  0.75173  3.868489
# ...    ...       ...      ...       ...
# 19995  6.0  0.627101  0.85470  0.029860
# 19996  6.0  0.114911  0.09566  0.010783
# 19997  6.0  0.614581  0.54444  0.004709
# 19998  6.0  0.223771  0.47553  0.155028
# 19999  6.0  0.645421  0.35118  0.106159
#
# [20000 rows x 4 columns]

# %%
def SPR(value):
    if value < 1:
        return 0
    if 1 <= value<2:
        return 2
    if 2 <= value<3:
        return 3
    if 3 <= value<4:
        return 4
    if 4<= value<5:
        return 5
    if 5<= value<6:
        return 6

# %%
A_test['SPR'] = A_test[3].map(SPR)
A_test
# Out:
#          0         1        2         3  SPR
# 0      4.0  0.000007  0.50958  3.714638  4.0
# 1      4.0  0.000008  0.54332  3.687126  4.0
# 2      4.0  0.000006  0.60987  3.797691  4.0
# 3      4.0  0.000009  0.95834  3.857651  4.0
# 4      4.0  0.000007  0.75173  3.868489  4.0
# ...    ...       ...      ...       ...  ...
# 19995  6.0  0.627101  0.85470  0.029860  0.0
# 19996  6.0  0.114911  0.09566  0.010783  0.0
# 19997  6.0  0.614581  0.54444  0.004709  0.0
# 19998  6.0  0.223771  0.47553  0.155028  0.0
# 19999  6.0  0.645421  0.35118  0.106159  0.0
#
# [20000 rows x 5 columns]

# %%
B_pred['SPR'] = B_pred[3].map(SPR)
B_pred
# Out:
#          0         1        2         3  SPR
# 0      4.0  0.000007  0.50958  3.700199    4
# 1      4.0  0.000008  0.54332  3.710379    4
# 2      4.0  0.000006  0.60987  3.730514    4
# 3      4.0  0.000009  0.95834  3.835795    4
# 4      4.0  0.000007  0.75173  3.773386    4
# ...    ...       ...      ...       ...  ...
# 19995  6.0  0.627101  0.85470  0.020017    0
# 19996  6.0  0.114911  0.09566  0.037846    0
# 19997  6.0  0.614581  0.54444  0.004970    0
# 19998  6.0  0.223771  0.47553  0.083453    0
# 19999  6.0  0.645421  0.35118  0.068538    0
#
# [20000 rows x 5 columns]

# %%
C3 = A_test.drop(A_test.columns[3], axis=1)
C3
# Out:
#          0         1        2  SPR
# 0      4.0  0.000007  0.50958  4.0
# 1      4.0  0.000008  0.54332  4.0
# 2      4.0  0.000006  0.60987  4.0
# 3      4.0  0.000009  0.95834  4.0
# 4      4.0  0.000007  0.75173  4.0
# ...    ...       ...      ...  ...
# 19995  6.0  0.627101  0.85470  0.0
# 19996  6.0  0.114911  0.09566  0.0
# 19997  6.0  0.614581  0.54444  0.0
# 19998  6.0  0.223771  0.47553  0.0
# 19999  6.0  0.645421  0.35118  0.0
#
# [20000 rows x 4 columns]

# %%
C4 = B_pred.drop(B_pred.columns[3], axis=1)
C4
# Out:
#          0         1        2  SPR
# 0      4.0  0.000007  0.50958    4
# 1      4.0  0.000008  0.54332    4
# 2      4.0  0.000006  0.60987    4
# 3      4.0  0.000009  0.95834    4
# 4      4.0  0.000007  0.75173    4
# ...    ...       ...      ...  ...
# 19995  6.0  0.627101  0.85470    0
# 19996  6.0  0.114911  0.09566    0
# 19997  6.0  0.614581  0.54444    0
# 19998  6.0  0.223771  0.47553    0
# 19999  6.0  0.645421  0.35118    0
#
# [20000 rows x 4 columns]

# %%
C4 = C4.rename(columns=dict(zip(C4.columns, C3.columns)))

# %%
C5=C3.compare(C4)
C5
# Out:
#        SPR
#       self other
# 352    5.0   4.0
# 3000   0.0   2.0
# 12930  NaN   6.0
# 13000  0.0   3.0

# %%
(5000-4)/5000
# Out:
# 0.9992

# %%
990+3984+1013
# Out:
# 5987

# %%
5987/6000
# Out:
# 0.9978333333333333
